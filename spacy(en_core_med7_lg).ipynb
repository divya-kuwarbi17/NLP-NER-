# %%
pip install spacy==2.3.5

# %%
pip install https://huggingface.co/kormilitzin/en_core_med7_trf/resolve/main/en_core_med7_trf-any-py3-none-any.whl

# %%
import spacy
med7 = spacy.load("en_core_med7_lg")

# %%
col_dict = {}
seven_colours = ['#e6194B', '#3cb44b', '#ffe119', '#ffd8b1', '#f58231', '#f032e6', '#42d4f4']
for label, colour in zip(med7.pipe_labels['ner'], seven_colours):
    col_dict[label] = colour

# %%
options = {'ents': med7.pipe_labels['ner'], 'colors':col_dict}

# %%
text = 'LV Fluids, Inj Xylocaine, Inj TT, Iny Pantodac. Inj Emeset, Inj Ceftriaxone, Inj Pan. Inj Paracip. Tab Urikind. TAB CEFTUM 500 MG }-0-1 X 5 DAYS. PAN 40 MG (BEFORE FOOD) 1-0-0 X 5 DAYS.TEROL-LA 2 MG g-0-1 X 10 DAYS. DOLO 630 MG SOS FOR PAIN FEVER. : ULTRASOUND KUB AFTER 10 DAYS. PLAN DJ STENT REMOVAL AFTER 10 DAYS.RFT, Hb%, ABG, PCV/2D ECHO, ECG,PT,APTT, CBC RBS Urine Routine ,Vitamin B12 Vitamin D25,LFT,LDL, VLDL CHOLESTEROL,TSH,HIV,HBSAG Cabgoline 0.5 mg 1-0-1 x 2 days . Ceftum 500 mg 1-0-1 x 5 days after food Tab. MetrogyI 400 mg 1-0-1 x 5 days after food , Tab. Imo] 500 mg 1-1-1 x 5 days after food ° Cap. Omez 1-0-1 x5 days before food. Cap. Globac XT 1-0-1 for 6months Tab. Shelcal 500mg 1-0-1 x 6months Cap. Becosule 0-1-0 for 6months Plenty of oral fluids Ambulation Avoid physical exertion x 6éweeks, Contraception after 6wks. 1. Polypod CV 200mg X Sdays (1-0-1) A/F. - 2. Rabekind DSR X 5days \1-0-2) BF. 3. Enzoflam X5days (1-0-1) A/F. IVF 2RL, 2DNS, 2NS@75cc/hr Pan D 1-0-1 _ Imol plus 1-0-1 Emanzen D 1-0-1 Creamaffin 2tsf T Bact ointment for LA RECOMMENDATIONS : Augmentin 625 MG 1-0-1 X TOTAL 5 DAYS Pan D 1-0-1 x TOTAL 5 DAYS mol plus 1 SOS PROCAS DF POWDER 2TSF 1-0-1 IN GLASS OF MILK'

# %%
doc = med7(text)

spacy.displacy.render(doc, style='ent', jupyter=True, options=options)

[(ent.text, ent.label_) for ent in doc.ents]
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">LV
# <mark class="entity" style="background: #3cb44b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fluids
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
# ,
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Inj
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STRENGTH</span>
# </mark>
#
# <mark class="entity" style="background: #3cb44b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Xylocaine
# ...
